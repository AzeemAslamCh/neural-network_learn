# %% [markdown]
# <a href="https://colab.research.google.com/github/AzeemAslamCh/neural-network_learn/blob/main/neural_networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("Cardiotocographic.csv")
df
# Out:
#       BPM       APC      FMPS      UCPS      DLPS  SDPS  PDPS  ASTV  MSTV  \
# 0     120  0.000000  0.000000  0.000000  0.000000   0.0   0.0    73   0.5
# 1     132  0.006380  0.000000  0.006380  0.003190   0.0   0.0    17   2.1
# 2     133  0.003322  0.000000  0.008306  0.003322   0.0   0.0    16   2.1
# 3     134  0.002561  0.000000  0.007682  0.002561   0.0   0.0    16   2.4
# 4     132  0.006515  0.000000  0.008143  0.000000   0.0   0.0    16   2.4
# ...   ...       ...       ...       ...       ...   ...   ...   ...   ...
# 2121  140  0.000000  0.000000  0.007426  0.000000   0.0   0.0    79   0.2
# 2122  140  0.000775  0.000000  0.006971  0.000000   0.0   0.0    78   0.4
# 2123  140  0.000980  0.000000  0.006863  0.000000   0.0   0.0    79   0.4
# 2124  140  0.000679  0.000000  0.006110  0.000000   0.0   0.0    78   0.4
# 2125  142  0.001616  0.001616  0.008078  0.000000   0.0   0.0    74   0.4
#
#       ALTV  MLTV  Width  Min  Max  NSP
# 0       43   2.4     64   62  126    2
# ...

# %%
df.head()
# Out:
#    BPM       APC  FMPS      UCPS      DLPS  SDPS  PDPS  ASTV  MSTV  ALTV  \
# 0  120  0.000000   0.0  0.000000  0.000000   0.0   0.0    73   0.5    43
# 1  132  0.006380   0.0  0.006380  0.003190   0.0   0.0    17   2.1     0
# 2  133  0.003322   0.0  0.008306  0.003322   0.0   0.0    16   2.1     0
# 3  134  0.002561   0.0  0.007682  0.002561   0.0   0.0    16   2.4     0
# 4  132  0.006515   0.0  0.008143  0.000000   0.0   0.0    16   2.4     0
#
#    MLTV  Width  Min  Max  NSP
# 0   2.4     64   62  126    2
# 1  10.4    130   68  198    1
# 2  13.4    130   68  198    1
# 3  23.0    117   53  170    1
# 4  19.9    117   53  170    1

# %%
df.tail()
# Out:
#       BPM       APC      FMPS      UCPS  DLPS  SDPS  PDPS  ASTV  MSTV  ALTV  \
# 2121  140  0.000000  0.000000  0.007426   0.0   0.0   0.0    79   0.2    25
# 2122  140  0.000775  0.000000  0.006971   0.0   0.0   0.0    78   0.4    22
# 2123  140  0.000980  0.000000  0.006863   0.0   0.0   0.0    79   0.4    20
# 2124  140  0.000679  0.000000  0.006110   0.0   0.0   0.0    78   0.4    27
# 2125  142  0.001616  0.001616  0.008078   0.0   0.0   0.0    74   0.4    36
#
#       MLTV  Width  Min  Max  NSP
# 2121   7.2     40  137  177    2
# 2122   7.1     66  103  169    2
# 2123   6.1     67  103  170    2
# 2124   7.0     66  103  169    2
# 2125   5.0     42  117  159    1

# %%
df.describe()
# Out:
#                BPM          APC         FMPS         UCPS         DLPS  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.303857     0.003170     0.009474     0.004357     0.001885
# std       9.840844     0.003860     0.046670     0.002940     0.002962
# min     106.000000     0.000000     0.000000     0.000000     0.000000
# 25%     126.000000     0.000000     0.000000     0.001876     0.000000
# 50%     133.000000     0.001630     0.000000     0.004482     0.000000
# 75%     140.000000     0.005631     0.002512     0.006525     0.003264
# max     160.000000     0.019284     0.480634     0.014925     0.015385
#
#               SDPS         PDPS         ASTV         MSTV        ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.00000
# mean      0.000004     0.000157    46.990122     1.332785     9.84666
# std       0.000063     0.000580    17.192814     0.883241    18.39688
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   BPM     2126 non-null   int64
#  1   APC     2126 non-null   float64
#  2   FMPS    2126 non-null   float64
#  3   UCPS    2126 non-null   float64
#  4   DLPS    2126 non-null   float64
#  5   SDPS    2126 non-null   float64
#  6   PDPS    2126 non-null   float64
#  7   ASTV    2126 non-null   int64
#  8   MSTV    2126 non-null   float64
#  9   ALTV    2126 non-null   int64
#  10  MLTV    2126 non-null   float64
#  11  Width   2126 non-null   int64
#  12  Min     2126 non-null   int64
#  13  Max     2126 non-null   int64
#  14  NSP     2126 non-null   int64
# dtypes: float64(8), int64(7)
# memory usage: 249.3 KB

# %%
df.shape
# Out:
# (2126, 15)

# %%
df['NSP'].value_counts()
# Out:
# 1    1655
# 2     295
# 3     176
# Name: NSP, dtype: int64

# %%
sns.countplot(df, x="NSP")
# Out:
# <Axes: xlabel='NSP', ylabel='count'>

# %%
X = df.drop('NSP',axis=1)
y = df['NSP'] -1
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify=y, random_state=0)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.fit_transform(X_test)

# %%
model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Dense(9,activation='relu',input_shape=(14,)))
model.add(tf.keras.layers.Dense(3,activation='softmax'))

# %%
model.compile(optimizer='adam',
            loss='sparse_categorical_crossentropy',
            metrics='accuracy')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 9)                 135
#
#  dense_1 (Dense)             (None, 3)                 30
#
# ...
# Total params: 165 (660.00 Byte)
# Trainable params: 165 (660.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
class_weights = { 0:1, 1:6.5, 2:9.4}

history = model.fit(X_train, y_train, \
                  batch_size = 32, epochs= 50, \
                  verbose=2, class_weight=class_weights, \
                  validation_split=0.2)
# Out:
# Epoch 1/50
# 43/43 - 0s - loss: 0.5333 - accuracy: 0.8949 - val_loss: 0.3557 - val_accuracy: 0.8706 - 315ms/epoch - 7ms/step
# Epoch 2/50
# 43/43 - 0s - loss: 0.5317 - accuracy: 0.8912 - val_loss: 0.3564 - val_accuracy: 0.8706 - 351ms/epoch - 8ms/step
# Epoch 3/50
# 43/43 - 0s - loss: 0.5291 - accuracy: 0.8912 - val_loss: 0.3567 - val_accuracy: 0.8706 - 279ms/epoch - 6ms/step
# Epoch 4/50
# 43/43 - 0s - loss: 0.5319 - accuracy: 0.8919 - val_loss: 0.3564 - val_accuracy: 0.8735 - 259ms/epoch - 6ms/step
# Epoch 5/50
# 43/43 - 0s - loss: 0.5281 - accuracy: 0.8941 - val_loss: 0.3571 - val_accuracy: 0.8706 - 141ms/epoch - 3ms/step
# Epoch 6/50
# 43/43 - 0s - loss: 0.5304 - accuracy: 0.8919 - val_loss: 0.3592 - val_accuracy: 0.8706 - 143ms/epoch - 3ms/step
# Epoch 7/50
# 43/43 - 0s - loss: 0.5283 - accuracy: 0.8926 - val_loss: 0.3565 - val_accuracy: 0.8706 - 139ms/epoch - 3ms/step
# Epoch 8/50
# ...

# %%
accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']
plt.plot(accuracy, label='Training Set Accuracy')
plt.plot(validation_accuracy, label='Validation Set Accuracy')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy Across Epochs')
plt.legend()

# %%
loss = history.history['loss']
validation_loss = history.history['val_loss']
plt.plot(loss, label='Training Set Loss')
plt.plot(validation_loss, label='Validation Set Loss')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Across Epochs')
# Out:
# Text(0.5, 1.0, 'Training and Validation Loss Across Epochs')

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
y_pred = model.predict(X_test)
y_pred = y_pred.argmax(axis=1)
# Out:
# 14/14 [==============================] - 0s 1ms/step

# %%
confusion_matrix = confusion_matrix(y_test,y_pred)

ax = sns.heatmap(confusion_matrix, cmap='flare',annot=True, fmt='d')
plt.xlabel("Predicted Class",fontsize=12)
plt.ylabel("True Class",fontsize=12)
plt.title("Confusion Matrix",fontsize=12)
plt.show()

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.86      0.91       332
#            1       0.55      0.92      0.69        59
#            2       0.78      0.83      0.81        35
#
#     accuracy                           0.86       426
#    macro avg       0.77      0.87      0.80       426
# weighted avg       0.90      0.86      0.87       426
